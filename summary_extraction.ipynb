# %% [markdown]
# <a href="https://colab.research.google.com/github/usamullah/chat-with-pdf-/blob/main/summary_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install malaya
# Out:
# Collecting malaya
#   Downloading malaya-5.1.1-py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 28.1 MB/s eta 0:00:00
# Collecting dateparser (from malaya)
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.10/dist-packages (from malaya) (1.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from malaya) (2.31.0)
# Collecting unidecode (from malaya)
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from malaya) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from malaya) (1.11.4)
# Collecting ftfy (from malaya)
#   Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from malaya) (3.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from malaya) (0.1.99)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from malaya) (4.66.2)
# Collecting malaya-boilerplate>=0.0.25 (from malaya)
#   Downloading malaya_boilerplate-0.0.25-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from malaya) (2023.12.25)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from malaya) (4.40.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from malaya-boilerplate>=0.0.25->malaya) (0.20.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2->malaya) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2->malaya) (3.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateparser->malaya) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser->malaya) (2023.4)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser->malaya) (5.2)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->malaya) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->malaya) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->malaya) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->malaya) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->malaya) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->malaya) (3.13.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->malaya) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->malaya) (6.0.1)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->malaya) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->malaya) (0.4.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->malaya-boilerplate>=0.0.25->malaya) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->malaya-boilerplate>=0.0.25->malaya) (4.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->dateparser->malaya) (1.16.0)
# Installing collected packages: unidecode, ftfy, dateparser, malaya-boilerplate, malaya
# Successfully installed dateparser-1.2.0 ftfy-6.2.0 malaya-5.1.1 malaya-boilerplate-0.0.25 unidecode-1.3.8

# %%
# pip install --upgrade malaya

# %%
# pip install tokenizer
# Out:
# Collecting tokenizer
#   Downloading tokenizer-3.4.3-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: tokenizer
# Successfully installed tokenizer-3.4.3

# %%
dir(malaya.preprocessing)
# Out:
# ['Callable',
#  'Demoji',
#  'List',
#  'Preprocessing',
#  'Tokenizer',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_annotate',
#  '_expressions',
#  '_get_expression_dict',
#  '_normalize',
#  'case_of',
#  'demoji',
#  'ftfy',
#  'get_annotate',
#  'get_normalize',
#  'is_english',
#  'json',
#  'logger',
#  'logging',
#  'lru_cache',
#  'preprocessing',
#  're',
#  'rejected',
#  'rules_normalizer',
#  'unpack_english_contractions',
#  'validator']

# %%
dir(malaya.preprocessing.Tokenizer)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'tokenize',
#  'wrap_non_matching']

# %%
import malaya
import re
from malaya.text.function import split_into_sentences
from malaya.text import regex
tokenizer = malaya.preprocessing.Tokenizer()

# tokenizer = malaya.preprocessing._tokenizer
# import tokenizer
splitter = split_into_sentences
# Out:
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=TypeError("IPythonKernel.do_execute() missing 1 required positional argument: 'silent'")>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 216, in wrapper
#     result = ctx_run(func, *args, **kwargs)
# TypeError: IPythonKernel.do_execute() missing 1 required positional argument: 'silent'
# /usr/local/lib/python3.10/dist-packages/malaya/tokenizer.py:214: FutureWarning: Possible nested set at position 3397
#   self.tok = re.compile(r'({})'.format('|'.join(pipeline)))
# /usr/local/lib/python3.10/dist-packages/malaya/tokenizer.py:214: FutureWarning: Possible nested set at position 3927
#   self.tok = re.compile(r'({})'.format('|'.join(pipeline)))

# %%
dir(malaya.text)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'bahasa',
#  'bpe',
#  'entity',
#  'function',
#  'jarowinkler',
#  'lexicon',
#  'ngram',
#  'normalization',
#  'rake',
#  'regex',
#  'rouge',
#  'rules',
#  'tatabahasa',
#  'unicode']

# %%
dir(malaya.text.function)
# Out:
# ['BETUL',
#  'BeautifulSoup',
#  'GEMBIRA',
#  'MENGELUH',
#  'NUMBERS',
#  'PHONES',
#  'PUNCTUATION',
#  'SM',
#  'STOPWORDS',
#  'STOPWORD_CALON',
#  'VOWELS',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_expressions',
#  'acronyms',
#  'alphabets',
#  'another_websites',
#  'augmentation_textcleaning',
#  'available_bs4',
#  'before_digits',
#  'bigbird_postprocessing',
#  'build_dataset',
#  'case_of',
#  'check_ratio_numbers',
#  'check_ratio_punct',
#  'check_ratio_upper_lower',
#  'classification_textcleaning',
#  'classification_textcleaning_stemmer',
#  'collections',
#  'combinations',
#  'digits',
#  'emails',
#  'emoji',
#  'entities_textcleaning',
#  'fuzzy_substring_search',
#  'generate_compound',
#  'get_hashtags',
#  'get_similar_substrings',
#  'get_stopwords',
#  'get_stopwords_calon',
#  'is_emoji',
#  'is_laugh',
#  'is_mengeluh',
#  'isword_english',
#  'isword_malay',
#  'itertools',
#  'language_detection_textcleaning',
#  'laughing',
#  'logger',
#  'logging',
#  'make_cleaning',
#  'malaya_textcleaning',
#  'maxlen_slide',
#  'mengeluh',
#  'month',
#  'multireplace',
#  'ngrams',
#  'normalized_chars',
#  'normalizer_textcleaning',
#  'pad_sentence_batch',
#  'phoneme_textcleaning',
#  'pos_entities_textcleaning',
#  'prefixes',
#  'print_topics_modeling',
#  'question_cleaning',
#  're',
#  'reject_word',
#  'remove_empty_parenthesis',
#  'remove_html_tags',
#  'remove_newlines',
#  'remove_parenthesis',
#  'remove_repeat_fullstop',
#  'replace_punct',
#  'replace_sub',
#  'rules_normalizer',
#  'rumi_jawi_textcleaning',
#  'separate_dataset',
#  'simple_textcleaning',
#  'split_by_dot',
#  'split_into_sentences',
#  'split_nya',
#  'starters',
#  'stopword_tatabahasa',
#  'stopwords',
#  'stopwords_calon',
#  'suffixes',
#  'summarization_textcleaning',
#  'summary_textcleaning',
#  'tag_chunk',
#  'transformer_textcleaning',
#  'translation_textcleaning',
#  'unidecode',
#  'upperfirst',
#  'websites',
#  'word']

# %%
# pip install bert

# %%
dir(bert)
# Out:
# ['Atom',
#  'BERTDecoder',
#  'BERTEncoder',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'codec',
#  'decode',
#  'encode']

# %%
pip install bert
# Out:
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=TypeError("IPythonKernel.do_execute() missing 1 required positional argument: 'silent'")>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 216, in wrapper
#     result = ctx_run(func, *args, **kwargs)
# TypeError: IPythonKernel.do_execute() missing 1 required positional argument: 'silent'
# Requirement already satisfied: bert in /usr/local/lib/python3.10/dist-packages (2.2.0)
# Requirement already satisfied: erlastic in /usr/local/lib/python3.10/dist-packages (from bert) (2.0.0)

# %%
# !wget https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip
# !unzip uncased_L-12_H-768_A-12.zip
# Out:
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=TypeError("IPythonKernel.do_execute() missing 1 required positional argument: 'silent'")>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 216, in wrapper
#     result = ctx_run(func, *args, **kwargs)
# TypeError: IPythonKernel.do_execute() missing 1 required positional argument: 'silent'
# --2024-04-24 06:22:27--  https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.167.207, 64.233.180.207, 142.251.16.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.167.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 407727028 (389M) [application/zip]
# Saving to: ‘uncased_L-12_H-768_A-12.zip.2’
#
# uncased_L-12_H-768_ 100%[===================>] 388.84M  14.4MB/s    in 5.2s
#
# 2024-04-24 06:22:32 (74.7 MB/s) - ‘uncased_L-12_H-768_A-12.zip.2’ saved [407727028/407727028]
#
# Archive:  uncased_L-12_H-768_A-12.zip
# replace uncased_L-12_H-768_A-12/bert_model.ckpt.meta? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# from bert import tokenization

# BERT_VOCAB = 'uncased_L-12_H-768_A-12/vocab.txt'
# tokenizer = tokenization.FullTokenizer(vocab_file=BERT_VOCAB, do_lower_case=True)
# Out:
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=TypeError("IPythonKernel.do_execute() missing 1 required positional argument: 'silent'")>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 216, in wrapper
#     result = ctx_run(func, *args, **kwargs)
# TypeError: IPythonKernel.do_execute() missing 1 required positional argument: 'silent'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-dd4f8a64aba9> in <cell line: 1>()
# ----> 1 from bert import tokenization
#       2
#       3 BERT_VOCAB = 'uncased_L-12_H-768_A-12/vocab.txt'
#       4 tokenizer = tokenization.FullTokenizer(vocab_file=BERT_VOCAB, do_lower_case=True)
#
# ImportError: cannot import name 'tokenization' from 'bert' (/usr/local/lib/python3.10/dist-packages/bert/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from transformers import BertTokenizer

BERT_VOCAB = 'uncased_L-12_H-768_A-12/vocab.txt'
tokenizer = BertTokenizer.from_pretrained(BERT_VOCAB)

# %%
import glob

book = glob.glob('story.pdf')

print(len(book))
print(type(book))
# Out:
# 1
# <class 'list'>

# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
from PyPDF2 import PdfReader

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        pdf_reader = PdfReader(file)
        num_pages = len(pdf_reader.pages)
        for page_number in range(num_pages):
            page = pdf_reader.pages[page_number]
            text += page.extract_text()
            # print(text)
    return text


# Example usage
pdf_file = 'story.pdf'  # Replace 'example.pdf' with the path to your PDF file
stories = extract_text_from_pdf(pdf_file)
print(len(stories))
print(type(stories))
# Out:
# 136045
# <class 'str'>

# %%
def is_number_regex(s):
    if re.match("^\d+?\.\d+?$", s) is None:
        return s.isdigit()
    return True

def preprocessing(string):
    string = re.sub('[^\'"A-Za-z\-(),.$0-9 ]+', ' ', string.lower())
    tokenized =  tokenizer(string)
    tokens = []
    for w in tokenized:
        if is_number_regex(w):
            tokens.append('<NUM>')
        elif re.match(regex._money, w):
            tokens.append('<MONEY>')
        elif re.match(regex._date, w):
            tokens.append('<DATE>')
        else:
            tokens.append(w)

    return tokens


def split_story(doc):
    index = doc.find('@highlight')
    story, highlights = doc[:index], doc[index:].split('@highlight')
    highlights = [h.strip() for h in highlights if len(h) > 0]
    stories = []
    for s in splitter(story):
        stories.append(preprocessing(s))
    summaries = []
    for s in highlights:
        summaries.append(preprocessing(s))
    print(stories)
    print(summaries)
    return stories, summaries

# %%
min_src_nsents = 3
max_src_nsents = 20
min_src_ntokens_per_sent = 5
max_src_ntokens_per_sent = 30
min_tgt_ntokens = 5
max_tgt_ntokens = 500
sep_token = '[SEP]'
cls_token = '[CLS]'

# %%
story, highlights = split_story(stories)
# Out:
# [['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_ ...
# [['input_ids', 'token_type_ids', 'attention_mask']]

# %%
def _get_ngrams(n, text):
    ngram_set = set()
    text_length = len(text)
    max_index_ngram_start = text_length - n
    for i in range(max_index_ngram_start + 1):
        ngram_set.add(tuple(text[i:i + n]))
    return ngram_set


def _get_word_ngrams(n, sentences):
    assert len(sentences) > 0
    assert n > 0

    words = sum(sentences, [])
    return _get_ngrams(n, words)

def cal_rouge(evaluated_ngrams, reference_ngrams):
    reference_count = len(reference_ngrams)
    evaluated_count = len(evaluated_ngrams)

    overlapping_ngrams = evaluated_ngrams.intersection(reference_ngrams)
    overlapping_count = len(overlapping_ngrams)

    if evaluated_count == 0:
        precision = 0.0
    else:
        precision = overlapping_count / evaluated_count

    if reference_count == 0:
        recall = 0.0
    else:
        recall = overlapping_count / reference_count

    f1_score = 2.0 * ((precision * recall) / (precision + recall + 1e-8))
    return {"f": f1_score, "p": precision, "r": recall}


def greedy_selection(doc_sent_list, abstract_sent_list, summary_size):
    def _rouge_clean(s):
        return re.sub(r'[^a-zA-Z0-9 ]', '', s)

    max_rouge = 0.0
    abstract = sum(abstract_sent_list, [])
    abstract = _rouge_clean(' '.join(abstract)).split()
    sents = [_rouge_clean(' '.join(s)).split() for s in doc_sent_list]
    evaluated_1grams = [_get_word_ngrams(1, [sent]) for sent in sents]
    reference_1grams = _get_word_ngrams(1, [abstract])
    evaluated_2grams = [_get_word_ngrams(2, [sent]) for sent in sents]
    reference_2grams = _get_word_ngrams(2, [abstract])

    selected = []
    for s in range(summary_size):
        cur_max_rouge = max_rouge
        cur_id = -1
        for i in range(len(sents)):
            if (i in selected):
                continue
            c = selected + [i]
            candidates_1 = [evaluated_1grams[idx] for idx in c]
            candidates_1 = set.union(*map(set, candidates_1))
            candidates_2 = [evaluated_2grams[idx] for idx in c]
            candidates_2 = set.union(*map(set, candidates_2))
            rouge_1 = cal_rouge(candidates_1, reference_1grams)['f']
            rouge_2 = cal_rouge(candidates_2, reference_2grams)['f']
            rouge_score = rouge_1 + rouge_2
            if rouge_score > cur_max_rouge:
                cur_max_rouge = rouge_score
                cur_id = i
        if (cur_id == -1):
            return selected
        selected.append(cur_id)
        max_rouge = cur_max_rouge

    return sorted(selected)

def get_xy(story, highlights):
    idxs = [i for i, s in enumerate(story) if (len(s) > min_src_ntokens_per_sent)]

    idxs = [i for i, s in enumerate(story) if (len(s) > min_src_ntokens_per_sent)]

    src = [story[i][:max_src_ntokens_per_sent] for i in idxs]
    src = src[:max_src_nsents]

    sent_labels = greedy_selection(src, highlights, 3)

    _sent_labels = [0] * len(src)
    for l in sent_labels:
        _sent_labels[l] = 1
    _sent_labels

    src_txt = [' '.join(sent) for sent in src]
    text = ' {} {} '.format(sep_token, cls_token).join(src_txt)
    text = '[CLS] %s [SEP]'%(text)
    cls_ids = [i for i, t in enumerate(text.split()) if t == cls_token]

    return text, cls_ids, _sent_labels

# %%
import collections
import json

def build_dataset(words, n_words, atleast=1):
    count = [['PAD', 0], ['GO', 1], ['EOS', 2], ['UNK', 3]]
    counter = collections.Counter(words).most_common(n_words)
    counter = [i for i in counter if i[1] >= atleast]
    count.extend(counter)
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
from dask import delayed
import dask

def process(i):
    story, highlights = split_story(stories)
    return get_xy(story, highlights)

train = []
for i in range(len(stories)):
    im = delayed(process)(i)
    train.append(im)
    print(train)
train = dask.compute(*train)
# Out:
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c'), Delayed('process-673c1d1e-a0a2-46af-ad62-03dde6ff5e60')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c'), Delayed('process-673c1d1e-a0a2-46af-ad62-03dde6ff5e60'), Delayed('process-15774209-efda-4e3b-9906-1f4ba5ae6177')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c'), Delayed('process-673c1d1e-a0a2-46af-ad62-03dde6ff5e60'), Delayed('process-15774209-efda-4e3b-9906-1f4ba5ae6177'), Delayed('process-dd39dc33-e484-4fec-98a9-1ba6e2113087')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c'), Delayed('process-673c1d1e-a0a2-46af-ad62-03dde6ff5e60'), Delayed('process-15774209-efda-4e3b-9906-1f4ba5ae6177'), Delayed('process-dd39dc33-e484-4fec-98a9-1ba6e2113087'), Delayed('process-5d669f83-dfd8-46ff-b6db-4d4763758689')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c'), Delayed('process-673c1d1e-a0a2-46af-ad62-03dde6ff5e60'), Delayed('process-15774209-efda-4e3b-9906-1f4ba5ae6177'), Delayed('process-dd39dc33-e484-4fec-98a9-1ba6e2113087'), Delayed('process-5d669f83-dfd8-46ff-b6db-4d4763758689'), Delayed('process-379938e2-9a4a-4de4-9398-6945765fae7e')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c'), Delayed('process-673c1d1e-a0a2-46af-ad62-03dde6ff5e60'), Delayed('process-15774209-efda-4e3b-9906-1f4ba5ae6177'), Delayed('process-dd39dc33-e484-4fec-98a9-1ba6e2113087'), Delayed('process-5d669f83-dfd8-46ff-b6db-4d4763758689'), Delayed('process-379938e2-9a4a-4de4-9398-6945765fae7e'), Delayed('process-f44a298a-330c-46ac-9374-6bfb7c2e45b6')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c'), Delayed('process-673c1d1e-a0a2-46af-ad62-03dde6ff5e60'), Delayed('process-15774209-efda-4e3b-9906-1f4ba5ae6177'), Delayed('process-dd39dc33-e484-4fec-98a9-1ba6e2113087'), Delayed('process-5d669f83-dfd8-46ff-b6db-4d4763758689'), Delayed('process-379938e2-9a4a-4de4-9398-6945765fae7e'), Delayed('process-f44a298a-330c-46ac-9374-6bfb7c2e45b6'), Delayed('process-50df4362-2594-4a23-8939-02d1d6816c28')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c'), Delayed('process-673c1d1e-a0a2-46af-ad62-03dde6ff5e60'), Delayed('process-15774209-efda-4e3b-9906-1f4ba5ae6177'), Delayed('process-dd39dc33-e484-4fec-98a9-1ba6e2113087'), Delayed('process-5d669f83-dfd8-46ff-b6db-4d4763758689'), Delayed('process-379938e2-9a4a-4de4-9398-6945765fae7e'), Delayed('process-f44a298a-330c-46ac-9374-6bfb7c2e45b6'), Delayed('process-50df4362-2594-4a23-8939-02d1d6816c28'), Delayed('process-5eda6e02-c8bc-4823-870d-1c9846ee2df9')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c'), Delayed('process-673c1d1e-a0a2-46af-ad62-03dde6ff5e60'), Delayed('process-15774209-efda-4e3b-9906-1f4ba5ae6177'), Delayed('process-dd39dc33-e484-4fec-98a9-1ba6e2113087'), Delayed('process-5d669f83-dfd8-46ff-b6db-4d4763758689'), Delayed('process-379938e2-9a4a-4de4-9398-6945765fae7e'), Delayed('process-f44a298a-330c-46ac-9374-6bfb7c2e45b6'), Delayed('process-50df4362-2594-4a23-8939-02d1d6816c28'), Delayed('process-5eda6e02-c8bc-4823-870d-1c9846ee2df9'), Delayed('process-4848dab0-9aaa-427d-af2f-c97880a07a60')]
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c'), Delayed('process-673c1d1e-a0a2-46af-ad62-03dde6ff5e60'), Delayed('process-15774209-efda-4e3b-9906-1f4ba5ae6177'), Delayed('process-dd39dc33-e484-4fec-98a9-1ba6e2113087'), Delayed('process-5d669f83-dfd8-46ff-b6db-4d4763758689'), Delayed('process-379938e2-9a4a-4de4-9398-6945765fae7e'), Delayed('process-f44a298a-330c-46ac-9374-6bfb7c2e45b6'), Delayed('process-50df4362-2594-4a23-8939-02d1d6816c28'), Delayed('process-5eda6e02-c8bc-4823-870d-1c9846ee2df9'), Delayed('process-4848dab0-9aaa-427d-af2f-c97880a07a60'), Delayed('process-ea914da7-2506-4584-998b-e517143d7df2')]
# ...
# [Delayed('process-f15676c2-7856-49ef-bb69-eba057f4d539'), Delayed('process-8871b585-cf09-41bb-9ed4-9ff9ad65cb38'), Delayed('process-8ee5cd26-ef04-42db-b67d-60cb3e200bde'), Delayed('process-63a3f978-9461-43a4-aac4-65d4a9c52f13'), Delayed('process-76ca6806-e535-4443-a46f-f4fec843a3f7'), Delayed('process-e7202cef-e4e8-41f8-9498-b2688ce59209'), Delayed('process-823ddd8a-ce46-46d2-91be-d7da40301940'), Delayed('process-42c0995e-03fa-4aed-a50f-89c5fb7a6610'), Delayed('process-c294f66e-f42f-4d9a-986f-8ba2fb268602'), Delayed('process-112c1433-14eb-4cd9-8616-023e3f71711d'), Delayed('process-36b8f9de-102e-4c1a-9b14-99f75c8b444c'), Delayed('process-65185f9c-4913-443c-867b-c2894ed2968f'), Delayed('process-c034f3e9-e10a-443b-ac1a-a41a41536ed0'), Delayed('process-4992816f-fd65-4792-93bc-669e96ab9c2a'), Delayed('process-786e70d2-b6d5-4239-a7d3-aeec9af292cb'), Delayed('process-af517ace-7921-41ca-bebc-9936be9aee8d'), Delayed('process-ec4add4b-cb4a-40ba-9530-71d6fbf01e96'), Delayed('process-f5eac015-edcc-4c84-a5a1-c7324e2d261a'), Delayed('process-c4fedccf-c106-4098-955d-4c6efa7d230c'), Delayed('process-1317bb0b-2275-475d-a750-00a5d39a4259'), Delayed('process-1fd05111-94f9-48c0-9e96-041a34a12a3f'), Delayed('process-6b887091-6909-4477-90d9-56b94700ed5e'), Delayed('process-0ab5112f-7ebd-4fe6-947b-34f06adf0297'), Delayed('process-d40472bc-bbe4-42e0-a2be-32cdd505628f'), Delayed('process-cafb885c-4a84-4cef-9eb8-74a29ec291cf'), Delayed('process-b0e7efdd-5a07-4ba3-8b0d-b289fa784b6e'), Delayed('process-8688554f-c0ed-4af7-a3fc-553b7cb848d3'), Delayed('process-c3605710-a86a-4a47-b38c-a21923882b72'), Delayed('process-06c12b5c-7095-45eb-8bff-a23331171de6'), Delayed('process-1a283c1a-0b3a-4196-9469-3dd308e38c7c'), Delayed('process-673c1d1e-a0a2-46af-ad62-03dde6ff5e60'), Delayed('process-15774209-efda-4e3b-9906-1f4ba5ae6177'), Delayed('process-dd39dc33-e484-4fec-98a9-1ba6e2113087'), Delayed('process-5d669f83-dfd8-46ff-b6db-4d4763758689'), Delayed('process-379938e2-9a4a-4de4-9398-6945765fae7e'), Delayed('process-f44a298a-330c-46ac-9374-6bfb7c2e45b6'), Delayed('process-50df4362-2594-4a23-8939-02d1d6816c28'), Delayed('process-5eda6e02-c8bc-4823-870d-1c9846ee2df9'), Delayed('process-4848dab0-9aaa-427d-af2f-c97880a07a60'), Delayed('process-ea914da7-2506-4584-998b-e517143d7df2'), Delayed('process-8bc0a73a-1134-4e30-b68a-a05704cf1302'), Delayed('process-00245199-6917-4ea3-a43e-e3f96c0cb0c7'), Delayed('process-15fd5f60-5f37-427b-936b-65e851cc1489'), Delayed('process-eba57bdf-7e6d-4caa-b036-b46221f0d5ab'), Delayed('process-467b7ad9-dc00-4297-95bf-a670c837287e'), Delayed('process-92aaab85-f510-4724-96e8-b46d1915
             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
#     402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in _is_master_process(self)
#     307
#     308     def _is_master_process(self):
# --> 309         return os.getpid() == self._master_pid
#     310
#     311     def set_parent(self, parent):
#
# KeyboardInterrupt:

# %%
story, highlights = split_story(stories)
text, cls_ids, sent_labels = get_xy(stories, highlights)
# Out:
# [['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_type_ids', 'attention_mask'], ['input_ids', 'token_ ...
# [['input_ids', 'token_type_ids', 'attention_mask']]

# %%
len(sent_labels), len(cls_ids), len(text.split())
# Out:
# (0, 1, 2)

# %%
# # Check the current values
# !jupyter notebook --generate-config

# %%
#
import IPython
IPython.get_ipython().events.register('pre_run_cell', lambda : IPython.get_ipython().kernel.do_execute('!echo "{\"NotebookApp\": {\"iopub_data_rate_limit\": 10000000}}" > ~/.jupyter/jupyter_notebook_config.json'))

# %%
# Out:
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=TypeError("IPythonKernel.do_execute() missing 1 required positional argument: 'silent'")>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 216, in wrapper
#     result = ctx_run(func, *args, **kwargs)
# TypeError: IPythonKernel.do_execute() missing 1 required positional argument: 'silent'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-fb0207a8be65> in <cell line: 1>()
# ----> 1 c.NotebookApp.iopub_data_rate_limit = 2000000  # Set the data rate limit to 10 MB/s
#
# NameError: name 'c' is not defined

# %%
from tqdm import tqdm

texts, clss, labels = [], [], []

for i in tqdm(range(len(stories))):
    with open(stories[i]) as fopen:
        story = fopen.read()
    story, highlights = split_story(story)
    text, cls_ids, sent_labels = get_xy(story, highlights)
    if len(cls_ids) != len(sent_labels):
        continue
    texts.append(text)
    clss.append(cls_ids)
    labels.append(sent_labels)
# Out:
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=TypeError("IPythonKernel.do_execute() missing 1 required positional argument: 'silent'")>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 216, in wrapper
#     result = ctx_run(func, *args, **kwargs)
# TypeError: IPythonKernel.do_execute() missing 1 required positional argument: 'silent'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f2ce97d45655> in <cell line: 5>()
#       3 texts, clss, labels = [], [], []
#       4
# ----> 5 for i in tqdm(range(len(stories))):
#       6     with open(stories[i]) as fopen:
#       7         story = fopen.read()
#
# NameError: name 'stories' is not defined

# %%
concat = ' '.join(texts).split()
vocabulary_size = len(list(set(concat)))
_, count, dictionary, rev_dictionary = build_dataset(concat, vocabulary_size, atleast = 2)
print('vocab from size: %d'%(len(dictionary)))
print('Most common words', count[4:10])

# %%
from sklearn.model_selection import train_test_split

train_texts, test_texts, train_clss, test_clss, train_labels, test_labels = \
train_test_split(texts, clss, labels, test_size = 0.2)

# %%
import pickle

with open('dataset.pkl', 'wb') as fopen:
    pickle.dump({'train_texts': train_texts,
                'test_texts': test_texts,
                'train_clss': train_clss,
                'test_clss': test_clss,
                'train_labels': train_labels,
                'test_labels': test_labels}, fopen)

# %%
with open('dictionary.pkl', 'wb') as fopen:
    pickle.dump({'dictionary': dictionary, 'rev_dictionary': rev_dictionary}, fopen)

# %%
# def split_story(doc):
#     index = doc.find('@highlight')
#     story, highlights = doc[:index], doc[index:].split('@highlight')
#     highlights = [h.strip() for h in highlights if len(h) > 0]
#     stories = []
#     for s in splitter(story):
#         stories.append(s.split())
#     summaries = []
#     for s in highlights:
#         summaries.append(s.split())
#     return stories, summaries

# %%
# min_src_nsents = 3
# max_src_nsents = 20
# min_src_ntokens_per_sent = 5
# max_src_ntokens_per_sent = 30
# min_tgt_ntokens = 5
# max_tgt_ntokens = 500
# sep_token = '[SEP]'
# cls_token = '[CLS]'
# pad_token = '[PAD]'
# tgt_bos = '[unused0]'
# tgt_eos = '[unused1]'
# tgt_sent_split = '[unused2]'
# sep_vid = tokenizer.vocab[sep_token]
# cls_vid = tokenizer.vocab[cls_token]
# pad_vid = tokenizer.vocab[pad_token]

# %%
# story, highlights = split_story(book)

# %%
# def _get_ngrams(n, text):
#     ngram_set = set()
#     text_length = len(text)
#     max_index_ngram_start = text_length - n
#     for i in range(max_index_ngram_start + 1):
#         ngram_set.add(tuple(text[i:i + n]))
#     return ngram_set


# def _get_word_ngrams(n, sentences):
#     assert len(sentences) > 0
#     assert n > 0

#     words = sum(sentences, [])
#     return _get_ngrams(n, words)

# def cal_rouge(evaluated_ngrams, reference_ngrams):
#     reference_count = len(reference_ngrams)
#     evaluated_count = len(evaluated_ngrams)

#     overlapping_ngrams = evaluated_ngrams.intersection(reference_ngrams)
#     overlapping_count = len(overlapping_ngrams)

#     if evaluated_count == 0:
#         precision = 0.0
#     else:
#         precision = overlapping_count / evaluated_count

#     if reference_count == 0:
#         recall = 0.0
#     else:
#         recall = overlapping_count / reference_count

#     f1_score = 2.0 * ((precision * recall) / (precision + recall + 1e-8))
#     return {"f": f1_score, "p": precision, "r": recall}


# def greedy_selection(doc_sent_list, abstract_sent_list, summary_size):
#     def _rouge_clean(s):
#         return re.sub(r'[^a-zA-Z0-9 ]', '', s)

#     max_rouge = 0.0
#     abstract = sum(abstract_sent_list, [])
#     abstract = _rouge_clean(' '.join(abstract)).split()
#     sents = [_rouge_clean(' '.join(s)).split() for s in doc_sent_list]
#     evaluated_1grams = [_get_word_ngrams(1, [sent]) for sent in sents]
#     reference_1grams = _get_word_ngrams(1, [abstract])
#     evaluated_2grams = [_get_word_ngrams(2, [sent]) for sent in sents]
#     reference_2grams = _get_word_ngrams(2, [abstract])

#     selected = []
#     for s in range(summary_size):
#         cur_max_rouge = max_rouge
#         cur_id = -1
#         for i in range(len(sents)):
#             if (i in selected):
#                 continue
#             c = selected + [i]
#             candidates_1 = [evaluated_1grams[idx] for idx in c]
#             candidates_1 = set.union(*map(set, candidates_1))
#             candidates_2 = [evaluated_2grams[idx] for idx in c]
#             candidates_2 = set.union(*map(set, candidates_2))
#             rouge_1 = cal_rouge(candidates_1, reference_1grams)['f']
#             rouge_2 = cal_rouge(candidates_2, reference_2grams)['f']
#             rouge_score = rouge_1 + rouge_2
#             if rouge_score > cur_max_rouge:
#                 cur_max_rouge = rouge_score
#                 cur_id = i
#         if (cur_id == -1):
#             return selected
#         selected.append(cur_id)
#         max_rouge = cur_max_rouge

#     return sorted(selected)

# def get_xy(story, highlights):
#     idxs = [i for i, s in enumerate(story) if (len(s) > min_src_ntokens_per_sent)]

#     idxs = [i for i, s in enumerate(story) if (len(s) > min_src_ntokens_per_sent)]

#     src = [story[i][:max_src_ntokens_per_sent] for i in idxs]
#     src = src[:max_src_nsents]

#     sent_labels = greedy_selection(src, highlights, 3)

#     _sent_labels = [0] * len(src)
#     for l in sent_labels:
#         _sent_labels[l] = 1
#     _sent_labels

#     src_txt = [' '.join(sent) for sent in src]
#     src_subtokens = []
#     for i, text in enumerate(src_txt):
#         text = tokenizer.tokenize(text)
#         if i > 0:
#             text = ['[SEP]','[CLS]'] + text
#         src_subtokens.extend(text)

#     src_subtokens = [cls_token] + src_subtokens + [sep_token]
#     src_subtoken_idxs = tokenizer.convert_tokens_to_ids(src_subtokens)

#     _segs = [-1] + [i for i, t in enumerate(src_subtoken_idxs) if t == sep_vid]
#     segs = [_segs[i] - _segs[i - 1] for i in range(1, len(_segs))]
#     segments_ids = []
#     for i, s in enumerate(segs):
#         if (i % 2 == 0):
#             segments_ids += s * [0]
#         else:
#             segments_ids += s * [1]
#     cls_ids = [i for i, t in enumerate(src_subtoken_idxs) if t == cls_vid]

#     return src_subtoken_idxs, cls_ids, _sent_labels, segments_ids

# %%
# text, cls_ids, sent_labels, segments_ids = get_xy(story, highlights)

# %%
# len(sent_labels), len(cls_ids), len(text), len(segments_ids)
# Out:
# (20, 20, 332, 332)

# %%
# from tqdm import tqdm

# texts, clss, labels, segments = [], [], [], []

# for i in tqdm(range(len(book))):
#     story, highlights = split_story(book)
#     text, cls_ids, sent_labels, segments_ids = get_xy(story, highlights)
#     if len(cls_ids) != len(sent_labels):
#         continue
#     texts.append(text)
#     clss.append(cls_ids)
#     labels.append(sent_labels)
#     segments.append(segments_ids)
# Out:
#   0%|          | 38/136045 [00:03<3:34:18, 10.58it/s]Exception ignored in: <function _xla_gc_callback at 0x7aee5fe405e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 98, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
#   0%|          | 65/136045 [00:07<4:17:36,  8.80it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-737714d24249> in <cell line: 5>()
#       4
#       5 for i in tqdm(range(len(book))):
# ----> 6     story, highlights = split_story(book)
#       7     text, cls_ids, sent_labels, segments_ids = get_xy(story, highlights)
#       8     if len(cls_ids) != len(sent_labels):
#
# <ipython-input-29-bd059826e48f> in split_story(doc)
#       4     highlights = [h.strip() for h in highlights if len(h) > 0]
#       5     stories = []
# ----> 6     for s in splitter(story):
#       7         stories.append(s.split())
#       8     summaries = []
#
# /usr/local/lib/python3.10/dist-packages/malaya/text/function.py in split_into_sentences(text, minimum_length)
#     612     text = text.replace('\n', ' ')
#     613     text = re.sub(prefixes, '\\1<prd>', text)
# --> 614     text = replace_sub(emails, text)
#     615     text = replace_sub(_expressions['title'], text)
#     616     text = re.sub(websites, '<prd>\\1', text)
#
# /usr/local/lib/python3.10/dist-packages/malaya/text/function.py in replace_sub(pattern, text, replace_left, replace_right)
#     585
#     586 def replace_sub(pattern, text, replace_left='.', replace_right='<prd>'):
# --> 587     alls = re.findall(pattern, text)
#     588     for a in alls:
#     589         text = text.replace(a, a.replace(replace_left, replace_right))
#
# /usr/lib/python3.10/re.py in findall(pattern, string, flags)
#     238
#     239     Empty matches are included in the result."""
# --> 240     return _compile(pattern, flags).findall(string)
#     241
#     242 def finditer(pattern, string, flags=0):
#
# KeyboardInterrupt:

# %%
import bert
dir(bert)
# Out:
# ['Atom',
#  'BERTDecoder',
#  'BERTEncoder',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'codec',
#  'decode',
#  'encode']
